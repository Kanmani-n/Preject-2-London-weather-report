# %%
# importing numpy pandas mathplot , seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data set
data =pd.read_csv('london_weather_data_1979_to_2023.csv') # Load your csv file as data

# %%
data
# Out:
#            DATE     TX  Q_TX    TN  Q_TN     TG  Q_TG    SS  Q_SS   SD  ...  \
# 0      19790101   23.0     0 -75.0     0  -41.0     0  70.0     0  9.0  ...
# 1      19790102   16.0     0 -75.0     0  -26.0     0  17.0     0  8.0  ...
# 2      19790103   13.0     0 -72.0     0  -28.0     0   0.0     0  4.0  ...
# 3      19790104   -3.0     0 -65.0     0  -26.0     0   0.0     0  2.0  ...
# 4      19790105   56.0     0 -14.0     0   -8.0     0  20.0     0  1.0  ...
# ...         ...    ...   ...   ...   ...    ...   ...   ...   ...  ...  ...
# 16431  20231227  126.0     0  55.0     0   89.0     0   0.0     0  0.0  ...
# 16432  20231228  119.0     0  97.0     0  112.0     0   2.0     0  0.0  ...
# 16433  20231229  122.0     0  92.0     0  106.0     0   7.0     0  0.0  ...
# 16434  20231230  107.0     0  56.0     0   89.0     0   0.0     0  0.0  ...
# 16435  20231231  124.0     0  57.0     0   82.0     0   5.0     0  0.0  ...
#
#          RR  Q_RR    QQ  Q_QQ       PP  Q_PP    HU  Q_HU   CC  Q_CC
# 0       4.0     0  52.0     0  10190.0     0  83.0     0  2.0     0
# 1       0.0     0  27.0     0  10253.0     0  76.0     0  6.0     0
# 2       0.0     0  13.0     0  10205.0     0  86.0     0  5.0     0
# 3       0.0     0  13.0     0  10084.0     0  68.0     0  8.0     0
# 4       0.0     0  29.0     0  10225.0     0  73.0     0  6.0     0
# ...     ...   ...   ...   ...      ...   ...   ...   ...  ...   ...
# 16431  46.0     0  12.0     0  10067.0     0  89.0     0  8.0     0
# 16432  48.0     0  15.0     0  10051.0     0  81.0     0  7.0     0
# 16433   0.0     0  20.0     0  10071.0     0  78.0     0  6.0     0
# 16434  56.0     0  12.0     0  10046.0     0  87.0     0  7.0     0
# 16435  16.0     0  18.0     0   9891.0     0  85.0     0  7.0     0
#
# [16436 rows x 21 columns]

# %%
#converting data into dataframe
df=pd.DataFrame(data)

# %%
df
# Out:
#            DATE     TX  Q_TX    TN  Q_TN     TG  Q_TG    SS  Q_SS   SD  ...  \
# 0      19790101   23.0     0 -75.0     0  -41.0     0  70.0     0  9.0  ...
# 1      19790102   16.0     0 -75.0     0  -26.0     0  17.0     0  8.0  ...
# 2      19790103   13.0     0 -72.0     0  -28.0     0   0.0     0  4.0  ...
# 3      19790104   -3.0     0 -65.0     0  -26.0     0   0.0     0  2.0  ...
# 4      19790105   56.0     0 -14.0     0   -8.0     0  20.0     0  1.0  ...
# ...         ...    ...   ...   ...   ...    ...   ...   ...   ...  ...  ...
# 16431  20231227  126.0     0  55.0     0   89.0     0   0.0     0  0.0  ...
# 16432  20231228  119.0     0  97.0     0  112.0     0   2.0     0  0.0  ...
# 16433  20231229  122.0     0  92.0     0  106.0     0   7.0     0  0.0  ...
# 16434  20231230  107.0     0  56.0     0   89.0     0   0.0     0  0.0  ...
# 16435  20231231  124.0     0  57.0     0   82.0     0   5.0     0  0.0  ...
#
#          RR  Q_RR    QQ  Q_QQ       PP  Q_PP    HU  Q_HU   CC  Q_CC
# 0       4.0     0  52.0     0  10190.0     0  83.0     0  2.0     0
# 1       0.0     0  27.0     0  10253.0     0  76.0     0  6.0     0
# 2       0.0     0  13.0     0  10205.0     0  86.0     0  5.0     0
# 3       0.0     0  13.0     0  10084.0     0  68.0     0  8.0     0
# 4       0.0     0  29.0     0  10225.0     0  73.0     0  6.0     0
# ...     ...   ...   ...   ...      ...   ...   ...   ...  ...   ...
# 16431  46.0     0  12.0     0  10067.0     0  89.0     0  8.0     0
# 16432  48.0     0  15.0     0  10051.0     0  81.0     0  7.0     0
# 16433   0.0     0  20.0     0  10071.0     0  78.0     0  6.0     0
# 16434  56.0     0  12.0     0  10046.0     0  87.0     0  7.0     0
# 16435  16.0     0  18.0     0   9891.0     0  85.0     0  7.0     0
#
# [16436 rows x 21 columns]

# %%
df.describe() #descriptive startegy
# Out:
#                DATE            TX          Q_TX            TN          Q_TN  \
# count  1.643600e+04  16436.000000  16436.000000  16436.000000  16436.000000
# mean   2.001066e+07    154.686846      0.068082     76.016427      0.015454
# std    1.298742e+05     65.741246      0.251895     53.392049      0.123353
# min    1.979010e+07    -62.000000      0.000000   -118.000000      0.000000
# 25%    1.990040e+07    106.000000      0.000000     36.000000      0.000000
# 50%    2.001070e+07    151.000000      0.000000     78.000000      0.000000
# 75%    2.012095e+07    204.000000      0.000000    118.000000      0.000000
# max    2.023123e+07    402.000000      1.000000    223.000000      1.000000
#
#                  TG          Q_TG            SS     Q_SS            SD  ...  \
# count  16407.000000  16436.000000  16436.000000  16436.0  15361.000000  ...
# mean     115.373316      0.083962     43.153626      0.0      0.034633  ...
# std       57.457444      0.451623     39.992648      0.0      0.519639  ...
# min      -76.000000      0.000000      0.000000      0.0      0.000000  ...
# 25%       72.000000      0.000000      4.000000      0.0      0.000000  ...
# 50%      114.000000      0.000000     35.000000      0.0      0.000000  ...
# 75%      161.000000      0.000000     71.000000      0.0      0.000000  ...
# max      309.000000      9.000000    157.000000      0.0     22.000000  ...
#
#                  RR     Q_RR           QQ          Q_QQ            PP  \
# count  16436.000000  16436.0  16411.00000  16436.000000  16432.000000
# mean      16.791738      0.0    119.52020      0.017036  10153.889423
# std       37.614507      0.0     89.26958      0.355343    105.196268
# min        0.000000      0.0      0.00000      0.000000   9596.000000
# 25%        0.000000      0.0     42.00000      0.000000  10091.000000
# 50%        0.000000      0.0     96.00000      0.000000  10162.000000
# 75%       16.000000      0.0    187.00000      0.000000  10225.000000
# max      618.000000      0.0    402.00000      9.000000  10477.000000
#
#               Q_PP            HU          Q_HU            CC          Q_CC
# count  16436.00000  16379.000000  16436.000000  16418.000000  16436.000000
# mean       0.00219     76.283717      0.031212      5.256426      0.009978
# std        0.14039     10.520699      0.529104      2.091593      0.297885
# min        0.00000     33.000000      0.000000      0.000000      0.000000
# 25%        0.00000     69.000000      0.000000      4.000000      0.000000
# 50%        0.00000     77.000000      0.000000      6.000000      0.000000
# 75%        0.00000     84.000000      0.000000      7.000000      0.000000
# max        9.00000    100.000000      9.000000      9.000000      9.000000
#
# [8 rows x 21 columns]

# %%
# passing first five values
df.head()
# Out:
#        DATE    TX  Q_TX    TN  Q_TN    TG  Q_TG    SS  Q_SS   SD  ...   RR  \
# 0  19790101  23.0     0 -75.0     0 -41.0     0  70.0     0  9.0  ...  4.0
# 1  19790102  16.0     0 -75.0     0 -26.0     0  17.0     0  8.0  ...  0.0
# 2  19790103  13.0     0 -72.0     0 -28.0     0   0.0     0  4.0  ...  0.0
# 3  19790104  -3.0     0 -65.0     0 -26.0     0   0.0     0  2.0  ...  0.0
# 4  19790105  56.0     0 -14.0     0  -8.0     0  20.0     0  1.0  ...  0.0
#
#    Q_RR    QQ  Q_QQ       PP  Q_PP    HU  Q_HU   CC  Q_CC
# 0     0  52.0     0  10190.0     0  83.0     0  2.0     0
# 1     0  27.0     0  10253.0     0  76.0     0  6.0     0
# 2     0  13.0     0  10205.0     0  86.0     0  5.0     0
# 3     0  13.0     0  10084.0     0  68.0     0  8.0     0
# 4     0  29.0     0  10225.0     0  73.0     0  6.0     0
#
# [5 rows x 21 columns]

# %%
#passing last five values
df.tail()
# Out:
#            DATE     TX  Q_TX    TN  Q_TN     TG  Q_TG   SS  Q_SS   SD  ...  \
# 16431  20231227  126.0     0  55.0     0   89.0     0  0.0     0  0.0  ...
# 16432  20231228  119.0     0  97.0     0  112.0     0  2.0     0  0.0  ...
# 16433  20231229  122.0     0  92.0     0  106.0     0  7.0     0  0.0  ...
# 16434  20231230  107.0     0  56.0     0   89.0     0  0.0     0  0.0  ...
# 16435  20231231  124.0     0  57.0     0   82.0     0  5.0     0  0.0  ...
#
#          RR  Q_RR    QQ  Q_QQ       PP  Q_PP    HU  Q_HU   CC  Q_CC
# 16431  46.0     0  12.0     0  10067.0     0  89.0     0  8.0     0
# 16432  48.0     0  15.0     0  10051.0     0  81.0     0  7.0     0
# 16433   0.0     0  20.0     0  10071.0     0  78.0     0  6.0     0
# 16434  56.0     0  12.0     0  10046.0     0  87.0     0  7.0     0
# 16435  16.0     0  18.0     0   9891.0     0  85.0     0  7.0     0
#
# [5 rows x 21 columns]

# %%
#count of number of rows and coloumns
df.shape
# Out:
# (16436, 21)

# %%
#generating all the column names
df.columns
# Out:
# Index(['DATE', 'TX', 'Q_TX', 'TN', 'Q_TN', 'TG', 'Q_TG', 'SS', 'Q_SS', 'SD',
#        'Q_SD', 'RR', 'Q_RR', 'QQ', 'Q_QQ', 'PP', 'Q_PP', 'HU', 'Q_HU', 'CC',
#        'Q_CC'],
#       dtype='object')

# %%
#describes the data types and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16436 entries, 0 to 16435
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    16436 non-null  int64
#  1   TX      16436 non-null  float64
#  2   Q_TX    16436 non-null  int64
#  3   TN      16436 non-null  float64
#  4   Q_TN    16436 non-null  int64
#  5   TG      16407 non-null  float64
#  6   Q_TG    16436 non-null  int64
#  7   SS      16436 non-null  float64
#  8   Q_SS    16436 non-null  int64
#  9   SD      15361 non-null  float64
#  10  Q_SD    16436 non-null  int64
#  11  RR      16436 non-null  float64
#  12  Q_RR    16436 non-null  int64
#  13  QQ      16411 non-null  float64
#  14  Q_QQ    16436 non-null  int64
#  15  PP      16432 non-null  float64
#  16  Q_PP    16436 non-null  int64
#  17  HU      16379 non-null  float64
#  18  Q_HU    16436 non-null  int64
#  19  CC      16418 non-null  float64
#  20  Q_CC    16436 non-null  int64
# dtypes: float64(10), int64(11)
# memory usage: 2.6 MB

# %%
#shows the data types of all the columns
df.dtypes
# Out:
# DATE      int64
# TX      float64
# Q_TX      int64
# TN      float64
# Q_TN      int64
# TG      float64
# Q_TG      int64
# SS      float64
# Q_SS      int64
# SD      float64
# Q_SD      int64
# RR      float64
# Q_RR      int64
# QQ      float64
# Q_QQ      int64
# PP      float64
# Q_PP      int64
# HU      float64
# Q_HU      int64
# CC      float64
# Q_CC      int64
# dtype: object

# %%
#handling missing values

# %%
#finding whether there is any null values
df.isnull()
# Out:
#         DATE     TX   Q_TX     TN   Q_TN     TG   Q_TG     SS   Q_SS     SD  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16431  False  False  False  False  False  False  False  False  False  False
# 16432  False  False  False  False  False  False  False  False  False  False
# 16433  False  False  False  False  False  False  False  False  False  False
# 16434  False  False  False  False  False  False  False  False  False  False
# 16435  False  False  False  False  False  False  False  False  False  False
#
#        ...     RR   Q_RR     QQ   Q_QQ     PP   Q_PP     HU   Q_HU     CC  \
# 0      ...  False  False  False  False  False  False  False  False  False
# 1      ...  False  False  False  False  False  False  False  False  False
# 2      ...  False  False  False  False  False  False  False  False  False
# 3      ...  False  False  False  False  False  False  False  False  False
# 4      ...  False  False  False  False  False  False  False  False  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16431  ...  False  False  False  False  False  False  False  False  False
# 16432  ...  False  False  False  False  False  False  False  False  False
# 16433  ...  False  False  False  False  False  False  False  False  False
# 16434  ...  False  False  False  False  False  False  False  False  False
# 16435  ...  False  False  False  False  False  False  False  False  False
#
#         Q_CC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 16431  False
# 16432  False
# 16433  False
# 16434  False
# 16435  False
#
# [16436 rows x 21 columns]

# %%
#finding the na or none values
df.isna()
# Out:
#         DATE     TX   Q_TX     TN   Q_TN     TG   Q_TG     SS   Q_SS     SD  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16431  False  False  False  False  False  False  False  False  False  False
# 16432  False  False  False  False  False  False  False  False  False  False
# 16433  False  False  False  False  False  False  False  False  False  False
# 16434  False  False  False  False  False  False  False  False  False  False
# 16435  False  False  False  False  False  False  False  False  False  False
#
#        ...     RR   Q_RR     QQ   Q_QQ     PP   Q_PP     HU   Q_HU     CC  \
# 0      ...  False  False  False  False  False  False  False  False  False
# 1      ...  False  False  False  False  False  False  False  False  False
# 2      ...  False  False  False  False  False  False  False  False  False
# 3      ...  False  False  False  False  False  False  False  False  False
# 4      ...  False  False  False  False  False  False  False  False  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16431  ...  False  False  False  False  False  False  False  False  False
# 16432  ...  False  False  False  False  False  False  False  False  False
# 16433  ...  False  False  False  False  False  False  False  False  False
# 16434  ...  False  False  False  False  False  False  False  False  False
# 16435  ...  False  False  False  False  False  False  False  False  False
#
#         Q_CC
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 16431  False
# 16432  False
# 16433  False
# 16434  False
# 16435  False
#
# [16436 rows x 21 columns]

# %%
#describes the sum of all na or none values in each column (count)
df.isna().sum()
# Out:
# DATE       0
# TX         0
# Q_TX       0
# TN         0
# Q_TN       0
# TG        29
# Q_TG       0
# SS         0
# Q_SS       0
# SD      1075
# Q_SD       0
# RR         0
# Q_RR       0
# QQ        25
# Q_QQ       0
# PP         4
# Q_PP       0
# HU        57
# Q_HU       0
# CC        18
# Q_CC       0
# dtype: int64

# %%
#if any na values exist then it is dropped or removed 
df.dropna()
# Out:
#            DATE     TX  Q_TX    TN  Q_TN     TG  Q_TG    SS  Q_SS   SD  ...  \
# 0      19790101   23.0     0 -75.0     0  -41.0     0  70.0     0  9.0  ...
# 1      19790102   16.0     0 -75.0     0  -26.0     0  17.0     0  8.0  ...
# 2      19790103   13.0     0 -72.0     0  -28.0     0   0.0     0  4.0  ...
# 3      19790104   -3.0     0 -65.0     0  -26.0     0   0.0     0  2.0  ...
# 4      19790105   56.0     0 -14.0     0   -8.0     0  20.0     0  1.0  ...
# ...         ...    ...   ...   ...   ...    ...   ...   ...   ...  ...  ...
# 16431  20231227  126.0     0  55.0     0   89.0     0   0.0     0  0.0  ...
# 16432  20231228  119.0     0  97.0     0  112.0     0   2.0     0  0.0  ...
# 16433  20231229  122.0     0  92.0     0  106.0     0   7.0     0  0.0  ...
# 16434  20231230  107.0     0  56.0     0   89.0     0   0.0     0  0.0  ...
# 16435  20231231  124.0     0  57.0     0   82.0     0   5.0     0  0.0  ...
#
#          RR  Q_RR    QQ  Q_QQ       PP  Q_PP    HU  Q_HU   CC  Q_CC
# 0       4.0     0  52.0     0  10190.0     0  83.0     0  2.0     0
# 1       0.0     0  27.0     0  10253.0     0  76.0     0  6.0     0
# 2       0.0     0  13.0     0  10205.0     0  86.0     0  5.0     0
# 3       0.0     0  13.0     0  10084.0     0  68.0     0  8.0     0
# 4       0.0     0  29.0     0  10225.0     0  73.0     0  6.0     0
# ...     ...   ...   ...   ...      ...   ...   ...   ...  ...   ...
# 16431  46.0     0  12.0     0  10067.0     0  89.0     0  8.0     0
# 16432  48.0     0  15.0     0  10051.0     0  81.0     0  7.0     0
# 16433   0.0     0  20.0     0  10071.0     0  78.0     0  6.0     0
# 16434  56.0     0  12.0     0  10046.0     0  87.0     0  7.0     0
# 16435  16.0     0  18.0     0   9891.0     0  85.0     0  7.0     0
#
# [15264 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# DATE       0
# TX         0
# Q_TX       0
# TN         0
# Q_TN       0
# TG        29
# Q_TG       0
# SS         0
# Q_SS       0
# SD      1075
# Q_SD       0
# RR         0
# Q_RR       0
# QQ        25
# Q_QQ       0
# PP         4
# Q_PP       0
# HU        57
# Q_HU       0
# CC        18
# Q_CC       0
# dtype: int64

# %%
#duplicate values are identified here 
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16431    False
# 16432    False
# 16433    False
# 16434    False
# 16435    False
# Length: 16436, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes # finding datatype
# Out:
# DATE      int64
# TX      float64
# Q_TX      int64
# TN      float64
# Q_TN      int64
# TG      float64
# Q_TG      int64
# SS      float64
# Q_SS      int64
# SD      float64
# Q_SD      int64
# RR      float64
# Q_RR      int64
# QQ      float64
# Q_QQ      int64
# PP      float64
# Q_PP      int64
# HU      float64
# Q_HU      int64
# CC      float64
# Q_CC      int64
# dtype: object

# %%
df
# Out:
#            DATE     TX  Q_TX    TN  Q_TN     TG  Q_TG    SS  Q_SS   SD  ...  \
# 0      19790101   23.0     0 -75.0     0  -41.0     0  70.0     0  9.0  ...
# 1      19790102   16.0     0 -75.0     0  -26.0     0  17.0     0  8.0  ...
# 2      19790103   13.0     0 -72.0     0  -28.0     0   0.0     0  4.0  ...
# 3      19790104   -3.0     0 -65.0     0  -26.0     0   0.0     0  2.0  ...
# 4      19790105   56.0     0 -14.0     0   -8.0     0  20.0     0  1.0  ...
# ...         ...    ...   ...   ...   ...    ...   ...   ...   ...  ...  ...
# 16431  20231227  126.0     0  55.0     0   89.0     0   0.0     0  0.0  ...
# 16432  20231228  119.0     0  97.0     0  112.0     0   2.0     0  0.0  ...
# 16433  20231229  122.0     0  92.0     0  106.0     0   7.0     0  0.0  ...
# 16434  20231230  107.0     0  56.0     0   89.0     0   0.0     0  0.0  ...
# 16435  20231231  124.0     0  57.0     0   82.0     0   5.0     0  0.0  ...
#
#          RR  Q_RR    QQ  Q_QQ       PP  Q_PP    HU  Q_HU   CC  Q_CC
# 0       4.0     0  52.0     0  10190.0     0  83.0     0  2.0     0
# 1       0.0     0  27.0     0  10253.0     0  76.0     0  6.0     0
# 2       0.0     0  13.0     0  10205.0     0  86.0     0  5.0     0
# 3       0.0     0  13.0     0  10084.0     0  68.0     0  8.0     0
# 4       0.0     0  29.0     0  10225.0     0  73.0     0  6.0     0
# ...     ...   ...   ...   ...      ...   ...   ...   ...  ...   ...
# 16431  46.0     0  12.0     0  10067.0     0  89.0     0  8.0     0
# 16432  48.0     0  15.0     0  10051.0     0  81.0     0  7.0     0
# 16433   0.0     0  20.0     0  10071.0     0  78.0     0  6.0     0
# 16434  56.0     0  12.0     0  10046.0     0  87.0     0  7.0     0
# 16435  16.0     0  18.0     0   9891.0     0  85.0     0  7.0     0
#
# [16436 rows x 21 columns]

# %%
#count of a particular column is generated
a=df['TX'].value_counts()

# %%
a
# Out:
# TX
# 126.0    120
# 111.0    119
# 139.0    115
# 115.0    114
# 122.0    111
#         ...
# 357.0      1
# 354.0      1
# 371.0      1
# 402.0      1
# 339.0      1
# Name: count, Length: 380, dtype: int64

# %%
#gets the unique values from the specific column
df['DATE'].unique()
# Out:
# array([19790101, 19790102, 19790103, ..., 20231229, 20231230, 20231231],
#       shape=(16436,))

# %%
#renaming the column names if required

# %%
df=df.rename(columns={'TX': 'Daily Max Temp'})

# %%
df=df.rename(columns={'TN': 'Daily Min Temp'})

# %%
df=df.rename(columns={'TG': 'Daily Mean Temp'})

# %%
df=df.rename(columns={'SS': 'Sunshine Duration'})

# %%
df=df.rename(columns={'SD': 'Snow Depth'})

# %%
df=df.rename(columns={'RR': 'Precipitation Amt'})

# %%
df=df.rename(columns={'QQ': 'Global Radiation'})

# %%
df=df.rename(columns={'PP': 'Sealevel Pressure'})

# %%
df=df.rename(columns={'HU': 'Relative Humidity'})

# %%
df=df.rename(columns={'CC': 'Cloud Cover'})

# %%
#values inside the column is replaced if required
df.replace({'Q_TX':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_TN':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_SS':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_RR':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_QQ':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_PP':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_HU':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df.replace({'Q_CC':{1:'Suspect',0:'Valid',9:'Missing'}},inplace=True)

# %%
df
# Out:
#            DATE  Daily Max Temp   Q_TX  Daily Min Temp   Q_TN  \
# 0      19790101            23.0  Valid           -75.0  Valid
# 1      19790102            16.0  Valid           -75.0  Valid
# 2      19790103            13.0  Valid           -72.0  Valid
# 3      19790104            -3.0  Valid           -65.0  Valid
# 4      19790105            56.0  Valid           -14.0  Valid
# ...         ...             ...    ...             ...    ...
# 16431  20231227           126.0  Valid            55.0  Valid
# 16432  20231228           119.0  Valid            97.0  Valid
# 16433  20231229           122.0  Valid            92.0  Valid
# 16434  20231230           107.0  Valid            56.0  Valid
# 16435  20231231           124.0  Valid            57.0  Valid
#
#        Daily Mean Temp  Q_TG  Sunshine Duration   Q_SS  Snow Depth  ...  \
# 0                -41.0     0               70.0  Valid         9.0  ...
# 1                -26.0     0               17.0  Valid         8.0  ...
# 2                -28.0     0                0.0  Valid         4.0  ...
# 3                -26.0     0                0.0  Valid         2.0  ...
# 4                 -8.0     0               20.0  Valid         1.0  ...
# ...                ...   ...                ...    ...         ...  ...
# 16431             89.0     0                0.0  Valid         0.0  ...
# 16432            112.0     0                2.0  Valid         0.0  ...
# 16433            106.0     0                7.0  Valid         0.0  ...
# 16434             89.0     0                0.0  Valid         0.0  ...
# 16435             82.0     0                5.0  Valid         0.0  ...
#
#        Precipitation Amt   Q_RR Global Radiation   Q_QQ Sealevel Pressure  \
# 0                    4.0  Valid             52.0  Valid           10190.0
# 1                    0.0  Valid             27.0  Valid           10253.0
# 2                    0.0  Valid             13.0  Valid           10205.0
# 3                    0.0  Valid             13.0  Valid           10084.0
# 4                    0.0  Valid             29.0  Valid           10225.0
# ...                  ...    ...              ...    ...               ...
# 16431               46.0  Valid             12.0  Valid           10067.0
# 16432               48.0  Valid             15.0  Valid           10051.0
# 16433                0.0  Valid             20.0  Valid           10071.0
# 16434               56.0  Valid             12.0  Valid           10046.0
# 16435               16.0  Valid             18.0  Valid            9891.0
#
#         Q_PP Relative Humidity   Q_HU Cloud Cover   Q_CC
# 0      Valid              83.0  Valid         2.0  Valid
# 1      Valid              76.0  Valid         6.0  Valid
# 2      Valid              86.0  Valid         5.0  Valid
# 3      Valid              68.0  Valid         8.0  Valid
# 4      Valid              73.0  Valid         6.0  Valid
# ...      ...               ...    ...         ...    ...
# 16431  Valid              89.0  Valid         8.0  Valid
# 16432  Valid              81.0  Valid         7.0  Valid
# 16433  Valid              78.0  Valid         6.0  Valid
# 16434  Valid              87.0  Valid         7.0  Valid
# 16435  Valid              85.0  Valid         7.0  Valid
#
# [16436 rows x 21 columns]

# %%
#flitering
filtered_df=df[df['Snow Depth']==0.0]

# %%
filtered_df
# Out:
#            DATE  Daily Max Temp     Q_TX  Daily Min Temp   Q_TN  \
# 6      19790107            85.0    Valid           -53.0  Valid
# 7      19790108            58.0  Suspect            53.0  Valid
# 8      19790109            52.0    Valid            16.0  Valid
# 9      19790110            49.0    Valid            14.0  Valid
# 10     19790111            29.0    Valid             3.0  Valid
# ...         ...             ...      ...             ...    ...
# 16431  20231227           126.0    Valid            55.0  Valid
# 16432  20231228           119.0    Valid            97.0  Valid
# 16433  20231229           122.0    Valid            92.0  Valid
# 16434  20231230           107.0    Valid            56.0  Valid
# 16435  20231231           124.0    Valid            57.0  Valid
#
#        Daily Mean Temp  Q_TG  Sunshine Duration   Q_SS  Snow Depth  ...  \
# 6                 15.0     0                0.0  Valid         0.0  ...
# 7                 69.0     1                1.0  Valid         0.0  ...
# 8                 37.0     0               58.0  Valid         0.0  ...
# 9                 33.0     0               19.0  Valid         0.0  ...
# 10                26.0     0               68.0  Valid         0.0  ...
# ...                ...   ...                ...    ...         ...  ...
# 16431             89.0     0                0.0  Valid         0.0  ...
# 16432            112.0     0                2.0  Valid         0.0  ...
# 16433            106.0     0                7.0  Valid         0.0  ...
# 16434             89.0     0                0.0  Valid         0.0  ...
# 16435             82.0     0                5.0  Valid         0.0  ...
#
#        Precipitation Amt   Q_RR Global Radiation   Q_QQ Sealevel Pressure  \
# 6                   52.0  Valid             13.0  Valid           10252.0
# 7                    8.0  Valid             15.0  Valid           10187.0
# 8                   72.0  Valid             50.0  Valid           10117.0
# 9                   21.0  Valid             30.0  Valid            9870.0
# 10                  23.0  Valid             55.0  Valid            9896.0
# ...                  ...    ...              ...    ...               ...
# 16431               46.0  Valid             12.0  Valid           10067.0
# 16432               48.0  Valid             15.0  Valid           10051.0
# 16433                0.0  Valid             20.0  Valid           10071.0
# 16434               56.0  Valid             12.0  Valid           10046.0
# 16435               16.0  Valid             18.0  Valid            9891.0
#
#         Q_PP Relative Humidity   Q_HU Cloud Cover   Q_CC
# 6      Valid              93.0  Valid         8.0  Valid
# 7      Valid              95.0  Valid         8.0  Valid
# 8      Valid              86.0  Valid         4.0  Valid
# 9      Valid              87.0  Valid         7.0  Valid
# 10     Valid              78.0  Valid         1.0  Valid
# ...      ...               ...    ...         ...    ...
# 16431  Valid              89.0  Valid         8.0  Valid
# 16432  Valid              81.0  Valid         7.0  Valid
# 16433  Valid              78.0  Valid         6.0  Valid
# 16434  Valid              87.0  Valid         7.0  Valid
# 16435  Valid              85.0  Valid         7.0  Valid
#
# [15219 rows x 21 columns]

# %%
#filter using and operator with two Columns
f1 = df[(df['Snow Depth'] == 0.0) & (df['Precipitation Amt'] == 0.0)]

# %%
f1
# Out:
#            DATE  Daily Max Temp   Q_TX  Daily Min Temp   Q_TN  \
# 19     19790120            35.0  Valid           -10.0  Valid
# 26     19790127            45.0  Valid           -52.0  Valid
# 32     19790202            59.0  Valid            15.0  Valid
# 33     19790203            45.0  Valid           -41.0  Valid
# 34     19790204            60.0  Valid           -12.0  Valid
# ...         ...             ...    ...             ...    ...
# 16420  20231216           121.0  Valid            55.0  Valid
# 16421  20231217           128.0  Valid            93.0  Valid
# 16424  20231220           144.0  Valid            39.0  Valid
# 16426  20231222           136.0  Valid            88.0  Valid
# 16433  20231229           122.0  Valid            92.0  Valid
#
#        Daily Mean Temp  Q_TG  Sunshine Duration   Q_SS  Snow Depth  ...  \
# 19                31.0     0                0.0  Valid         0.0  ...
# 26               -18.0     0               21.0  Valid         0.0  ...
# 32                28.0     0               14.0  Valid         0.0  ...
# 33                 9.0     0               87.0  Valid         0.0  ...
# 34                16.0     0                1.0  Valid         0.0  ...
# ...                ...   ...                ...    ...         ...  ...
# 16420             85.0     0                0.0  Valid         0.0  ...
# 16421            107.0     0               16.0  Valid         0.0  ...
# 16424             82.0     0               10.0  Valid         0.0  ...
# 16426            107.0     0                0.0  Valid         0.0  ...
# 16433            106.0     0                7.0  Valid         0.0  ...
#
#        Precipitation Amt   Q_RR Global Radiation   Q_QQ Sealevel Pressure  \
# 19                   0.0  Valid             16.0  Valid           10092.0
# 26                   0.0  Valid             39.0  Valid            9977.0
# 32                   0.0  Valid             37.0  Valid            9989.0
# 33                   0.0  Valid             85.0  Valid           10077.0
# 34                   0.0  Valid             23.0  Valid           10006.0
# ...                  ...    ...              ...    ...               ...
# 16420                0.0  Valid             12.0  Valid           10388.0
# 16421                0.0  Valid             25.0  Valid           10343.0
# 16424                0.0  Valid             22.0  Valid           10185.0
# 16426                0.0  Valid             12.0  Valid           10131.0
# 16433                0.0  Valid             20.0  Valid           10071.0
#
#         Q_PP Relative Humidity   Q_HU Cloud Cover   Q_CC
# 19     Valid              93.0  Valid         7.0  Valid
# 26     Valid              90.0  Valid         4.0  Valid
# 32     Valid              82.0  Valid         5.0  Valid
# 33     Valid              82.0  Valid         1.0  Valid
# 34     Valid              89.0  Valid         8.0  Valid
# ...      ...               ...    ...         ...    ...
# 16420  Valid              90.0  Valid         8.0  Valid
# 16421  Valid              80.0  Valid         8.0  Valid
# 16424  Valid              85.0  Valid         5.0  Valid
# 16426  Valid              74.0  Valid         7.0  Valid
# 16433  Valid              78.0  Valid         6.0  Valid
#
# [7924 rows x 21 columns]

# %%
#sorting
sort_s=df.sort_values(by='Snow Depth')

# %%
sort_s
# Out:
#            DATE  Daily Max Temp     Q_TX  Daily Min Temp   Q_TN  \
# 31     19790201            40.0  Suspect            12.0  Valid
# 17     19790118            30.0    Valid            -2.0  Valid
# 18     19790119            72.0    Valid           -14.0  Valid
# 19     19790120            35.0    Valid           -10.0  Valid
# 20     19790121            15.0    Valid           -35.0  Valid
# ...         ...             ...      ...             ...    ...
# 11965  20111005           158.0  Suspect           151.0  Valid
# 11966  20111006           167.0    Valid           112.0  Valid
# 11967  20111007           167.0    Valid            92.0  Valid
# 13415  20150924           179.0    Valid           126.0  Valid
# 13453  20151101           135.0    Valid            63.0  Valid
#
#        Daily Mean Temp  Q_TG  Sunshine Duration   Q_SS  Snow Depth  ...  \
# 31                52.0     1                0.0  Valid         0.0  ...
# 17                 8.0     0                0.0  Valid         0.0  ...
# 18                 8.0     0                0.0  Valid         0.0  ...
# 19                31.0     0                0.0  Valid         0.0  ...
# 20                 0.0     0                0.0  Valid         0.0  ...
# ...                ...   ...                ...    ...         ...  ...
# 11965            175.0     1                4.0  Valid         NaN  ...
# 11966            135.0     0               69.0  Valid         NaN  ...
# 11967            130.0     0               14.0  Valid         NaN  ...
# 13415            157.0     0               53.0  Valid         NaN  ...
# 13453             97.0     0               25.0  Valid         NaN  ...
#
#        Precipitation Amt   Q_RR Global Radiation   Q_QQ Sealevel Pressure  \
# 31                 101.0  Valid             19.0  Valid            9949.0
# 17                   2.0  Valid             15.0  Valid           10186.0
# 18                  52.0  Valid             16.0  Valid           10091.0
# 19                   0.0  Valid             16.0  Valid           10092.0
# 20                   1.0  Valid             16.0  Valid           10217.0
# ...                  ...    ...              ...    ...               ...
# 11965               40.0  Valid             48.0  Valid           10166.0
# 11966                4.0  Valid            121.0  Valid           10102.0
# 11967                0.0  Valid             63.0  Valid           10182.0
# 13415                0.0  Valid            124.0  Valid           10143.0
# 13453                2.0  Valid             53.0  Valid           10285.0
#
#         Q_PP Relative Humidity   Q_HU Cloud Cover     Q_CC
# 31     Valid              96.0  Valid         8.0    Valid
# 17     Valid              82.0  Valid         8.0    Valid
# 18     Valid              85.0  Valid         8.0    Valid
# 19     Valid              93.0  Valid         7.0    Valid
# 20     Valid              98.0  Valid         NaN  Missing
# ...      ...               ...    ...         ...      ...
# 11965  Valid              79.0  Valid         8.0    Valid
# 11966  Valid              67.0  Valid         3.0    Valid
# 11967  Valid              71.0  Valid         4.0    Valid
# 13415  Valid              76.0  Valid         6.0    Valid
# 13453  Valid              99.0  Valid         8.0    Valid
#
# [16436 rows x 21 columns]

# %%
c=df['Daily Max Temp']
d=df['Sunshine Duration']

# %%
#Line Plot
plt.plot(c,d,color='#5E0E79' ) #ploting and giving color to the line
plt.title("LINE GRAPH",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family 
plt.grid(True,linestyle='--',linewidth=.8,alpha=.7,color='blue') #adding grid lines and style ,width of it
plt.xlabel('Max Temperature',color='#CC6CE7') #giving label for X axis and color of the label
plt.ylabel('Sun Shine',color='#CC6CE7') #giving label for Y axis and color of the label
plt.xticks([2,4,6,8])  #Points displayed on x axis 
plt.xticks([0,100,200,300,400]) #points displayed on Y axis
# Out:
# ([<matplotlib.axis.XTick at 0x1d3c1d16350>,
#   <matplotlib.axis.XTick at 0x1d3c1d9c7d0>,
#   <matplotlib.axis.XTick at 0x1d3c1d9cf50>,
#   <matplotlib.axis.XTick at 0x1d3c1d9d6d0>,
#   <matplotlib.axis.XTick at 0x1d3c1d9de50>],
#  [Text(0, 0, '0'),
#   Text(100, 0, '100'),
#   Text(200, 0, '200'),
#   Text(300, 0, '300'),
#   Text(400, 0, '400')])

# %%
categories=df['Daily Max Temp']
values=df['Cloud Cover']

# %%
#Bar Plot
plt.bar(categories,values,color='#D9571B')#ploting and giving color to the line
plt.title('Weather report',fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#9A6E0D'}) #describes the title and font family 
plt.xlabel('Maximum Temperature',color='#351fe3') #giving label for X axis
plt.ylabel('Cloud Cover',color='#351fe3') #giving label for Y axis
plt.xticks([0.2,0.4,0.5,0.8])  #Points displayed on x axis 
plt.xticks([0,2,4,6,8]) #points displayed on Y axis
# Out:
# ([<matplotlib.axis.XTick at 0x1d3c1dc7d90>,
#   <matplotlib.axis.XTick at 0x1d3d045fed0>,
#   <matplotlib.axis.XTick at 0x1d3d04c8690>,
#   <matplotlib.axis.XTick at 0x1d3d04c8e10>,
#   <matplotlib.axis.XTick at 0x1d3d04c9590>],
#  [Text(0, 0, '0'),
#   Text(2, 0, '2'),
#   Text(4, 0, '4'),
#   Text(6, 0, '6'),
#   Text(8, 0, '8')])

# %%
r=df['Sunshine Duration']

# %%
#plotting for Histogram
plt.hist(r,bins=3,color='#752249')#ploting and giving color 
plt.title("HISTOGRAM",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#9A6E0D'}) #describes the title and font family
# Out:
# Text(0.5, 1.0, 'HISTOGRAM')

# %%
#scatter Plotting
plt.scatter(c,d,color='#104B57') #ploting and giving color
plt.title("Scatter Plot",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#9A6E0D'}) #describes the title and font family 
plt.xlabel("Max Temperature",color='#572348')#label for X axis and color
plt.ylabel("Cloud Cover",color='#572348')#Label for Y axis and color
plt.xticks([0,100,200,300,400]) #values that are displayed on x axis 
plt.yticks([0,50,100,150,200]) #values that are displayed on Y axis
plt.grid(True,linestyle='--',linewidth=.8,alpha=.7,color='#6C11E4') #displaying the grid lines with style width and color

# %%
values=df['Sunshine Duration']
categories=df['Snow Depth']

# %%
#pie chart 
plt.pie(values,labels=categories,autopct='%1.1f%%') # ploting 
plt.title("PIE CHART",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family
# Out:
# Text(0.5, 1.0, 'PIE CHART')

# %%
#Line Plot
sns.lineplot(x='Sunshine Duration',y='Snow Depth',data=df,color='#5213E2') 
plt.title("Weather Line plot",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family
plt.grid(True,linestyle='--',linewidth=.8,alpha=.7,color='#13E2C6') #displaying the grid lines with style width and color

# %%
#Scatter plot
sns.scatterplot(x='Sunshine Duration',y='Snow Depth',data=df,color='#E21313') # Plotting and color of the plot
plt.title("Weather -scatterplot",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family
plt.grid(True,linestyle='--',linewidth=.8,alpha=.7,color='#6DE213') #displaying the grid lines with style width and color

# %%
#bar Plot
sns.barplot(x='Global Radiation',y='Snow Depth',data=df,color='#F4E863') # Plotting and color of the plot
plt.title("Weather -Bar diagram",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family)
plt.xticks([100,115,120,125,150]) #values that are displayed on x axis 
plt.yticks([0.2,0.4,0.6,0.8]) #values that are displayed on Y axis

# %%
#Histogram
sns.histplot(data=df,x='Sunshine Duration',bins=12,kde=True,color='#B3F463')
plt.title("Weather",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family

# %%
sizes=df['Daily Max Temp']
labels=df['Cloud Cover']

# %%
#Pie chart
plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=140) #size,label and angle 
plt.title("Pie Chart",fontdict={'fontsize':14,'fontname':'Arial','fontweight':'bold','color':'#26B6AC'}) #describes the title and font family
